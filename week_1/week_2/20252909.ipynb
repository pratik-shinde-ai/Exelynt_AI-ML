# %% [markdown]
# #Function

# %%
def myfuntion(fname , lname):
    print(f"My Name is {fname} {lname}" )

    
myfuntion("Pratik", "Shinde")
myfuntion("Soham","Naik")
# Out:
# My Name is Pratik Shinde
# My Name is Soham Naik

# %%
#keyword argument 
def print_value(*values):
    for i in values:
        print(i)
print_value(1,2,3,4,23,"praitk")
# Out:
# 1
# 2
# 3
# 4
# 23
# praitk

# %% [markdown]
# #lamda

# %%
addition=lambda a,b:a+b
addition(4,5)
# Out:
# 9

# %%
age1=lambda age:age>18
age1(2)
# Out:
# False

# %% [markdown]
# #Module or Package

# %%
import math
print(math.sqrt(625))
print(math.pi)
# Out:
# 25.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,23,4,54,3])
# Out:
# array([ 1, 23,  4, 54,  3])

# %% [markdown]
# # OOps concept in a Python
# class-it's blueprint of object --example 1.fruit
#
# object-it show the real world entity's. --example 1.mango,apple

# %%
class Myclass:# crating class
    x=5


p1=Myclass()#creating object
print(p1.x)
# Out:
# 5

# %%
#making Bankaccount using different method
class Bankaccount:
    def __init__(self,owner,balance):
        self.owner=owner
        self.balance=balance
    
    def deposite(self,amount):
        self.balance+=amount
        print(f"your deposite amount is  {amount} amd the currnent balance is {self.balance} "  )
    
    def credit(self,amount):
        if amount>self.balance:
            print("Your account have a no money")
        else:
            self.balance-=amount
            print(f"your balance is after credited {self.balance} ")
    def current_balance(self):
        return self.balance
    
person1=Bankaccount("pratik", 9000)
person1.credit(300)
# Out:
# your balance is after credited 8700

# %%
print("In a various fomain it have some importat momenteun in a various call it have some crushi")
