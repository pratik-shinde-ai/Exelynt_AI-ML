# %% [markdown]
# PANDAS

# %%
import pandas as pd

mydata={"name":["a", "b","c","d","e","f","g","h","i","j"],"age":[15,26,17,15,14,15,16,15,16,14],"mark":[67,68,68,68,57,45,75,45,54,75]}

mydata2=pd.DataFrame(mydata)

print(mydata2)
# Out:
#   name  age  mark
# 0    a   15    67
# 1    b   26    68
# 2    c   17    68
# 3    d   15    68
# 4    e   14    57
# 5    f   15    45
# 6    g   16    75
# 7    h   15    45
# 8    i   16    54
# 9    j   14    75

# %%
mydata2
# Out:
#   name  age  mark
# 0    a   15    67
# 1    b   26    68
# 2    c   17    68
# 3    d   15    68
# 4    e   14    57
# 5    f   15    45
# 6    g   16    75
# 7    h   15    45
# 8    i   16    54
# 9    j   14    75

# %%
a=[[2,53,5],[23,43,43]]
b=pd.Series(a)
print(b)
# Out:
# 0      [2, 53, 5]
# 1    [23, 43, 43]
# dtype: object

# %%
mydata=mydata2
mydata
# Out:
#   name  age  mark
# 0    a   15    67
# 1    b   26    68
# 2    c   17    68
# 3    d   15    68
# 4    e   14    57
# 5    f   15    45
# 6    g   16    75
# 7    h   15    45
# 8    i   16    54
# 9    j   14    75

# %%
import pandas as pd

df=pd.read_csv("data.csv")

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60  110.0       NaN     409.1
# 1          60    NaN     145.0     479.0
# 2          60    NaN     135.0     340.0
# 3          45  109.0     175.0     282.4
# 4          45  117.0       NaN     406.0
# ..        ...    ...       ...       ...
# 164        60  105.0     140.0     290.8
# 165        60  110.0     145.0     300.0
# 166        60  115.0     145.0     310.2
# 167        75  120.0     150.0     320.4
# 168        75  125.0     150.0     330.4
#
# [169 rows x 4 columns]

# %%
data=pd.DataFrame(df)
print(data)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60  110.0       NaN     409.1
# 1          60    NaN     145.0     479.0
# 2          60    NaN     135.0     340.0
# 3          45  109.0     175.0     282.4
# 4          45  117.0       NaN     406.0
# ..        ...    ...       ...       ...
# 164        60  105.0     140.0     290.8
# 165        60  110.0     145.0     300.0
# 166        60  115.0     145.0     310.2
# 167        75  120.0     150.0     320.4
# 168        75  125.0     150.0     330.4
#
# [169 rows x 4 columns]

# %%
print(data.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60  110.0       NaN     409.1
# 1        60    NaN     145.0     479.0
# 2        60    NaN     135.0     340.0
# 3        45  109.0     175.0     282.4
# 4        45  117.0       NaN     406.0

# %%
print(data[0:10])
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60  110.0       NaN     409.1
# 1        60    NaN     145.0     479.0
# 2        60    NaN     135.0     340.0
# 3        45  109.0     175.0     282.4
# 4        45  117.0       NaN     406.0
# 5        60  102.0     127.0     300.0
# 6        60  110.0     136.0     374.0
# 7        45  104.0     134.0     253.3
# 8        30  109.0       NaN     195.1
# 9        60   98.0     124.0     269.0

# %%
print(data.loc[[4]])
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 4        45  117.0       NaN     406.0

# %%
print(data)
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 1          60    NaN  145.000000     479.0
# 2          60    NaN  135.000000     340.0
# 3          45  109.0  175.000000     282.4
# 4          45  117.0  133.993976     406.0
# ..        ...    ...         ...       ...
# 164        60  105.0  140.000000     290.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [169 rows x 4 columns]

# %%
#new_data=data.dropna()
#print(new_data)

# %%
data
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 1          60    NaN  145.000000     479.0
# 2          60    NaN  135.000000     340.0
# 3          45  109.0  175.000000     282.4
# 4          45  117.0  133.993976     406.0
# ..        ...    ...         ...       ...
# 164        60  105.0  140.000000     290.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [169 rows x 4 columns]

# %%
data.fillna(68)# inplace=True
print(data)
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 1          60    NaN  145.000000     479.0
# 2          60    NaN  135.000000     340.0
# 3          45  109.0  175.000000     282.4
# 4          45  117.0  133.993976     406.0
# ..        ...    ...         ...       ...
# 164        60  105.0  140.000000     290.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [169 rows x 4 columns]

# %%
data
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 1          60    NaN  145.000000     479.0
# 2          60    NaN  135.000000     340.0
# 3          45  109.0  175.000000     282.4
# 4          45  117.0  133.993976     406.0
# ..        ...    ...         ...       ...
# 164        60  105.0  140.000000     290.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [169 rows x 4 columns]

# %%
a=data["Maxpulse"].mean()
print(data.fillna({"Maxpulse":a}))
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 1          60    NaN  145.000000     479.0
# 2          60    NaN  135.000000     340.0
# 3          45  109.0  175.000000     282.4
# 4          45  117.0  133.993976     406.0
# ..        ...    ...         ...       ...
# 164        60  105.0  140.000000     290.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [169 rows x 4 columns]

# %%
print(data)
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 1          60    NaN  145.000000     479.0
# 2          60    NaN  135.000000     340.0
# 3          45  109.0  175.000000     282.4
# 4          45  117.0  133.993976     406.0
# ..        ...    ...         ...       ...
# 164        60  105.0  140.000000     290.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [169 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
data.isna().sum()
# Out:
# Duration    0
# Pulse       2
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
data["Pulse"].value_counts()
# Out:
# Pulse
# 100.0    19
# 90.0     12
# 109.0     9
# 103.0     8
# 107.0     8
# 97.0      7
# 108.0     7
# 110.0     7
# 98.0      6
# 102.0     6
# 106.0     6
# 105.0     6
# 111.0     6
# 104.0     4
# 114.0     4
# 115.0     3
# 95.0      3
# 118.0     3
# 136.0     3
# 93.0      3
# 92.0      3
# 151.0     2
# 112.0     2
# 117.0     2
# 99.0      2
# 80.0      2
# 150.0     2
# 101.0     2
# 123.0     2
# 159.0     1
# 116.0     1
# 120.0     1
# 85.0      1
# 122.0     1
# 141.0     1
# 113.0     1
# 119.0     1
# 124.0     1
# 149.0     1
# 137.0     1
# 152.0     1
# 121.0     1
# 130.0     1
# 83.0      1
# 129.0     1
# 153.0     1
# 125.0     1
# Name: count, dtype: int64

# %%
print(data.head(20))
# Out:
#     Duration  Pulse    Maxpulse  Calories
# 0         60  110.0  133.993976     409.1
# 1         60    NaN  145.000000     479.0
# 2         60    NaN  135.000000     340.0
# 3         45  109.0  175.000000     282.4
# 4         45  117.0  133.993976     406.0
# 5         60  102.0  127.000000     300.0
# 6         60  110.0  136.000000     374.0
# 7         45  104.0  134.000000     253.3
# 8         30  109.0  133.993976     195.1
# 9         60   98.0  124.000000     269.0
# 10        60  103.0  147.000000     329.3
# 11        60  100.0  120.000000     250.7
# 12        60  106.0  128.000000     345.3
# 13        60  104.0  132.000000     379.3
# 14        60   98.0  123.000000     275.0
# 15        60   98.0  120.000000     215.2
# 16        60  100.0  120.000000     300.0
# 17        45   90.0  112.000000       NaN
# 18        60  103.0  123.000000     323.0
# 19        45   97.0  125.000000     243.0

# %%
data[(data["Pulse"]>99)& (data["Calories"]>299)]
# Out:
#      Duration  Pulse    Maxpulse  Calories
# 0          60  110.0  133.993976     409.1
# 4          45  117.0  133.993976     406.0
# 5          60  102.0  127.000000     300.0
# 6          60  110.0  136.000000     374.0
# 10         60  103.0  147.000000     329.3
# ..        ...    ...         ...       ...
# 158        60  114.0  150.000000     382.8
# 165        60  110.0  145.000000     300.0
# 166        60  115.0  145.000000     310.2
# 167        75  120.0  150.000000     320.4
# 168        75  125.0  150.000000     330.4
#
# [85 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
a=[1,2,3,4]
b=[5,6,7,8]
plt.plot(a,b)
plt.show()

# %%
b=[25,25,40,10]
lables=["om","chatinay","pratik","jaswant"]
plt.pie(b)
plt.show()
